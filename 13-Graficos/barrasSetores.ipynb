# %%
import pandas as pd
import seaborn as srn

base = pd.read_csv('./dados/insect.csv')
base.shape
# Out:
# (72, 2)

# %%
base.head()
# Out:
#    count spray
# 0     10     A
# 1      7     A
# 2     20     A
# 3     14     A
# 4     14     A

# %%
agrupado = base.groupby(['spray'])['count'].sum()
agrupado
# Out:
# spray
# A    174
# B    184
# C     25
# D     59
# E     42
# F    200
# Name: count, dtype: int64

# %%
agrupado.plot.bar()
# Out:
# <Axes: xlabel='spray'>

# %%
#mudar as cores das barras
agrupado.plot.bar(color=['blue', 'yellow', 'green', 'pink', 'orange', 'red'])
# Out:
# <Axes: xlabel='spray'>

# %%
agrupado.plot.pie(legend=True)
# Out:
# <Axes: ylabel='count'>
