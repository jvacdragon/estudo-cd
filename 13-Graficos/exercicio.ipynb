# %%
import pandas as pd
import seaborn as srn
import matplotlib.pyplot as plt

df = pd.read_csv('./dados/dados.csv', sep=';')
df.head()
# Out:
#    CODIGO               MUNICIPIO       PIB  VALOREMPENHO
# 0     106   SANTANA DO LIVRAMENTO  12240.76    1088666.10
# 1     113            SANTO ANGELO  16575.82     800669.92
# 2     118  SAO FRANCISCO DE ASSIS  12037.61     466122.80
# 3      13         CACAPAVA DO SUL  13674.54     485535.86
# 4     120             SAO GABRIEL  19912.38     533719.86

# %%
plt.scatter(x=df['VALOREMPENHO'], y=df['PIB'], facecolor='None', color='blue', marker='.')

# %%
df['VALOREMPENHO'].describe()
cidadePadrao = df.loc[df['VALOREMPENHO'] < 2*df['VALOREMPENHO'].std()]
plt.scatter(x=cidadePadrao['VALOREMPENHO'], y=cidadePadrao['PIB'], marker='.')

# %%
df['VALOREMPENHO'].describe()
# Out:
# count    1.870000e+02
# mean     1.299844e+05
# std      1.615491e+05
# min      1.721300e+02
# 25%      5.251718e+04
# 50%      8.422816e+04
# 75%      1.538961e+05
# max      1.442760e+06
# Name: VALOREMPENHO, dtype: float64

# %%
df['PIB'].describe()
# Out:
# count       187.000000
# mean      19808.741337
# std       16984.223244
# min        8236.630000
# 25%       13621.455000
# 50%       17206.190000
# 75%       21429.165000
# max      223848.220000
# Name: PIB, dtype: float64
